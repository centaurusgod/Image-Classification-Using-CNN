# %%
# 1. Install Dependencies and Setup

# %%
import tensorflow as tf
import os

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.experimental.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Image FIltering
import cv2
import imghdr

# %%
data_dir='data'

# %%
image_exts=['jpeg', 'jpg', 'png', 'bmp']

# %%
for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
#Loading data
import numpy as np
from matplotlib import pyplot as plt

# %%
data = tf.keras.preprocessing.image_dataset_from_directory('data')
# Out:
# Found 430 files belonging to 2 classes.

# %%
#Converting into numpy iterator
data_iterator = data.as_numpy_iterator()

# %%
#next batch of data
batch = data_iterator.next()

# %%
# 1: Himalayan Monal
# 2: Crow

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
batch[0].max()
# Out:
# 255.0

# %%
#scale data
data = data.map(lambda x,y: (x/255, y))
data.as_numpy_iterator().next()[0].max()
# Out:
# 1.0

# %%
#splitting data
total_size = len(data)
train_size = int(total_size * 0.7)+1
val_size = int(total_size * 0.2)+1
test_size =int(total_size*0.1)

# %%
val_size+test_size+train_size
# Out:
# 14

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
#Building deep learning model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model=Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 254, 254, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 14400)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3686656
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 10/10 [==============================] - 7s 329ms/step - loss: 1.0641 - accuracy: 0.4938 - val_loss: 0.6852 - val_accuracy: 0.5833
# Epoch 2/20
# 10/10 [==============================] - 4s 284ms/step - loss: 0.6750 - accuracy: 0.6156 - val_loss: 0.6912 - val_accuracy: 0.5104
# Epoch 3/20
# 10/10 [==============================] - 4s 319ms/step - loss: 0.6334 - accuracy: 0.6719 - val_loss: 0.5858 - val_accuracy: 0.7500
# Epoch 4/20
# 10/10 [==============================] - 4s 305ms/step - loss: 0.5281 - accuracy: 0.7437 - val_loss: 0.4357 - val_accuracy: 0.8854
# Epoch 5/20
# 10/10 [==============================] - 4s 306ms/step - loss: 0.4446 - accuracy: 0.8125 - val_loss: 0.3447 - val_accuracy: 0.8854
# Epoch 6/20
# 10/10 [==============================] - 5s 347ms/step - loss: 0.3775 - accuracy: 0.8250 - val_loss: 0.2791 - val_accuracy: 0.8854
# Epoch 7/20
# 10/10 [==============================] - 5s 342ms/step - loss: 0.2449 - accuracy: 0.9125 - val_loss: 0.2171 - val_accuracy: 0.9375
# Epoch 8/20
# 10/10 [==============================] - 5s 340ms/step - loss: 0.1732 - accuracy: 0.9500 - val_loss: 0.1679 - val_accuracy: 0.9583
# Epoch 9/20
# 10/10 [==============================] - 4s 337ms/step - loss: 0.1240 - accuracy: 0.9688 - val_loss: 0.0951 - val_accuracy: 0.9688
# Epoch 10/20
# 10/10 [==============================] - 5s 337ms/step - loss: 0.0945 - accuracy: 0.9750 - val_loss: 0.0771 - val_accuracy: 0.9792
# Epoch 11/20
# 10/10 [==============================] - 5s 323ms/step - loss: 0.0572 - accuracy: 0.9844 - val_loss: 0.0416 - val_accuracy: 0.9896
# Epoch 12/20
# 10/10 [==============================] - 5s 328ms/step - loss: 0.0523 - accuracy: 0.9781 - val_loss: 0.0503 - val_accuracy: 0.9792
# Epoch 13/20
# 10/10 [==============================] - 4s 306ms/step - loss: 0.0437 - accuracy: 0.9875 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 14/20
# 10/10 [==============================] - 4s 301ms/step - loss: 0.0248 - accuracy: 0.9937 - val_loss: 0.0187 - val_accuracy: 0.9896
# Epoch 15/20
# 10/10 [==============================] - 4s 292ms/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 16/20
# 10/10 [==============================] - 4s 306ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 17/20
# 10/10 [==============================] - 4s 302ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 18/20
# 10/10 [==============================] - 4s 292ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 19/20
# 10/10 [==============================] - 4s 296ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 20/20
# 10/10 [==============================] - 4s 296ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
# Performance evaluation
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)

# %%
print(f'PRECISION:{pre.result().numpy()}')
print(f'Accuracy:{acc.result().numpy()}')
print(f'Recall:{re.result().numpy()}')
# Out:
# PRECISION:1.0
# Accuracy:1.0
# Recall:1.0

# %%
img = cv2.imread('danfe.jpg')
plt.imshow(img)
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))

# %%
yhat
# Out:
# array([[0.9999994]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class: Himalayan Monal')
else:
    print(f'Predicted class: Crow')
# Out:
# Predicted class: Himalayan Monal

# %%
#Saving the training model
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','imageclassifier.h5'))

# %%
new_model = load_model(os.path.join('models','imageclassifier.h5'))

# %%
new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# array([[0.9999994]], dtype=float32)
